# %%
#@title Classificazione citofluorimetrica
import pandas as pd
import numpy as np
import requests

url = 'https://RiccardoGM.github.io/Covid19Project/Modules/FlowCitometryClassification.py'
r = requests.get(url)
with open('FlowCitometryClassification.py', 'w') as f:
  f.write(r.text)  
import FlowCitometryClassification as FCC

FCC.run_classification()
